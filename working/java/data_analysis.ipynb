# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import os

# %%
# Read csv file
dir_path = "/Users/teng/UBCO/mds_labs/block4/542/data/DevGPT/cleaned/"

df = pd.read_csv(os.path.join(dir_path, "pr_total.csv"))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53415 entries, 0 to 53414
# Data columns (total 41 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            53415 non-null  int64
#  1   Type                  53415 non-null  object
#  2   URL_pr                53415 non-null  object
#  3   Author                53415 non-null  object
#  4   RepoName              53415 non-null  object
#  5   RepoLanguage          52767 non-null  object
#  6   Number                53415 non-null  int64
#  7   Title_x               53415 non-null  object
#  8   Body                  51605 non-null  object
#  9   CreatedAt             53415 non-null  object
#  10  ClosedAt              49042 non-null  object
#  11  MergedAt              41371 non-null  object
#  12  UpdatedAt             53415 non-null  object
#  13  State                 53415 non-null  object
#  14  Additions             53415 non-null  int64
# ...

# %%
# Check programming language distribution
df.groupby(["RepoLanguage"]).count()
# Out:
#                   Unnamed: 0   Type  URL_pr  Author  RepoName  Number  \
# RepoLanguage
# C                       1844   1844    1844    1844      1844    1844
# C#                       363    363     363     363       363     363
# C++                     3210   3210    3210    3210      3210    3210
# CSS                      108    108     108     108       108     108
# Dart                     216    216     216     216       216     216
# Dockerfile               244    244     244     244       244     244
# Elixir                    36     36      36      36        36      36
# Go                      4994   4994    4994    4994      4994    4994
# HTML                     686    686     686     686       686     686
# Java                   10872  10872   10872   10872     10872   10872
# JavaScript              4469   4469    4469    4469      4469    4469
# Jupyter Notebook        1621   1621    1621    1621      1621    1621
# ...

# %% [markdown]
# # Filter out Bash languages
