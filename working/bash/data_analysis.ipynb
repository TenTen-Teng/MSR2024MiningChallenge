# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import os

# %%
# Read csv file
dir_path = "/Users/teng/UBCO/mds_labs/block4/542/data/DevGPT/cleaned/"

df = pd.read_csv(os.path.join(dir_path, "pr.csv"))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1008 entries, 0 to 1007
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1008 non-null   int64
#  1   Type               1008 non-null   object
#  2   URL_pr             1008 non-null   object
#  3   Author             1008 non-null   object
#  4   RepoName           1008 non-null   object
#  5   RepoLanguage       990 non-null    object
#  6   Number             1008 non-null   int64
#  7   Title              1008 non-null   object
#  8   Body               950 non-null    object
#  9   CreatedAt          1008 non-null   object
#  10  ClosedAt           902 non-null    object
#  11  MergedAt           765 non-null    object
#  12  UpdatedAt          1008 non-null   object
#  13  State              1008 non-null   object
#  14  Additions          1008 non-null   int64
#  15  Deletions          1008 non-null   int64
#  16  ChangedFiles       1008 non-null   int64
#  17  CommitsTotalCount  1008 non-null   int64
#  18  CommitShas         575 non-null    object
#  19  CommitSha          433 non-null    object
#  20  source_date        1008 non-null   int64
# dtypes: int64(7), object(14)
# memory usage: 165.5+ KB

# %%
# Check programming language distribution
df.groupby(["RepoLanguage"]).count()
# Out:
#                   Unnamed: 0  Type  URL_pr  Author  RepoName  Number  Title  \
# RepoLanguage
# C                         26    26      26      26        26      26     26
# C#                        14    14      14      14        14      14     14
# C++                       74    74      74      74        74      74     74
# CSS                        3     3       3       3         3       3      3
# Dart                       6     6       6       6         6       6      6
# Dockerfile                 5     5       5       5         5       5      5
# Elixir                     1     1       1       1         1       1      1
# Go                        97    97      97      97        97      97     97
# HTML                      21    21      21      21        21      21     21
# Java                      66    66      66      66        66      66     66
# JavaScript               123   123     123     123       123     123    123
# Jupyter Notebook          13    13      13      13        13      13     13
# Kotlin                     2     2       2       2         2       2      2
# PHP                       86    86      86      86        86      86     86
# Python                   180   180     180     180       180     180    180
# Ruby                       8     8       8       8         8       8      8
# SCSS                       6     6       6       6         6       6      6
# Shell                      9     9       9       9         9       9      9
# Solidity                   5     5       5       5         5       5      5
# TSQL                       4     4       4       4         4       4      4
# TypeScript               223   223     223     223       223     223    223
# Vue                       18    18      18      18        18      18     18
#
#                   Body  CreatedAt  ClosedAt  MergedAt  UpdatedAt  State  \
# RepoLanguage
# C                   20         26        26        20         26     26
# C#                  11         14        12         6         14     14
# C++                 73         74        66        53         74     74
# CSS                  3          3         3         0          3      3
# Dart                 6          6         0         0          6      6
# Dockerfile           5          5         5         5          5      5
# Elixir               1          1         1         0          1      1
# Go                  94         97        77        67         97     97
# HTML                21         21        21        21         21     21
# Java                66         66        64        40         66     66
# JavaScript         112        123       117       102        123    123
# Jupyter Notebook    13         13         6         6         13     13
# Kotlin               2          2         0         0          2      2
# PHP                 85         86        83        71         86     86
# Python             164        180       163       144        180    180
# Ruby                 8          8         8         8          8      8
# SCSS                 6          6         0         0          6      6
# Shell                9          9         9         9          9      9
# Solidity             5          5         5         0          5      5
# TSQL                 4          4         4         4          4      4
# TypeScript         209        223       204       188        223    223
# Vue                 15         18        10         9         18     18
#
#                   Additions  Deletions  ChangedFiles  CommitsTotalCount  \
# RepoLanguage
# C                        26         26            26                 26
# C#                       14         14            14                 14
# C++                      74         74            74                 74
# CSS                       3          3             3                  3
# Dart                      6          6             6                  6
# Dockerfile                5          5             5                  5
# Elixir                    1          1             1                  1
# Go                       97         97            97                 97
# HTML                     21         21            21                 21
# Java                     66         66            66                 66
# JavaScript              123        123           123                123
# Jupyter Notebook         13         13            13                 13
# Kotlin                    2          2             2                  2
# PHP                      86         86            86                 86
# Python                  180        180           180                180
# Ruby                      8          8             8                  8
# SCSS                      6          6             6                  6
# Shell                     9          9             9                  9
# Solidity                  5          5             5                  5
# TSQL                      4          4             4                  4
# TypeScript              223        223           223                223
# Vue                      18         18            18                 18
#
#                   CommitShas  CommitSha  source_date
# RepoLanguage
# C                         26          0           26
# C#                        14          0           14
# C++                        9         65           74
# CSS                        3          0            3
# Dart                       6          0            6
# Dockerfile                 5          0            5
# Elixir                     1          0            1
# Go                        39         58           97
# HTML                      21          0           21
# Java                      66          0           66
# JavaScript                72         51          123
# Jupyter Notebook          13          0           13
# Kotlin                     2          0            2
# PHP                       12         74           86
# Python                    92         88          180
# Ruby                       8          0            8
# SCSS                       6          0            6
# Shell                      9          0            9
# Solidity                   5          0            5
# TSQL                       4          0            4
# TypeScript               126         97          223
# Vue                       18          0           18

# %% [markdown]
# # Filter out Bash languages
