# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import os

# %%
# Read csv file
dir_path = "/Users/teng/UBCO/mds_labs/block4/542/data/DevGPT/cleaned/"

df = pd.read_csv(os.path.join(dir_path, "pr.csv"))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         147 non-null    int64
#  1   Type               147 non-null    object
#  2   URL                147 non-null    object
#  3   Author             147 non-null    object
#  4   RepoName           147 non-null    object
#  5   RepoLanguage       144 non-null    object
#  6   Number             147 non-null    int64
#  7   Title              147 non-null    object
#  8   Body               138 non-null    object
#  9   CreatedAt          147 non-null    object
#  10  ClosedAt           130 non-null    object
#  11  MergedAt           110 non-null    object
#  12  UpdatedAt          147 non-null    object
#  13  State              147 non-null    object
#  14  Additions          147 non-null    int64
#  15  Deletions          147 non-null    int64
#  16  ChangedFiles       147 non-null    int64
#  17  CommitsTotalCount  147 non-null    int64
#  18  CommitShas         96 non-null     object
#  19  ChatgptSharing     147 non-null    object
#  20  CommitSha          51 non-null     object
#  21  source_date        147 non-null    int64
# dtypes: int64(7), object(15)
# memory usage: 25.4+ KB

# %%
# Check programming language distribution
df.groupby(["RepoLanguage"]).count()
# Out:
#                   Unnamed: 0  Type  URL  Author  RepoName  Number  Title  \
# RepoLanguage
# C                          5     5    5       5         5       5      5
# C#                         2     2    2       2         2       2      2
# C++                        2     2    2       2         2       2      2
# CSS                        1     1    1       1         1       1      1
# Dart                       1     1    1       1         1       1      1
# Dockerfile                 2     2    2       2         2       2      2
# Elixir                     1     1    1       1         1       1      1
# Go                         7     7    7       7         7       7      7
# HTML                       4     4    4       4         4       4      4
# Java                      10    10   10      10        10      10     10
# JavaScript                63    63   63      63        63      63     63
# Jupyter Notebook           1     1    1       1         1       1      1
# PHP                        2     2    2       2         2       2      2
# Python                    14    14   14      14        14      14     14
# Ruby                       1     1    1       1         1       1      1
# SCSS                       1     1    1       1         1       1      1
# Shell                      1     1    1       1         1       1      1
# Solidity                   1     1    1       1         1       1      1
# TypeScript                21    21   21      21        21      21     21
# Vue                        4     4    4       4         4       4      4
#
#                   Body  CreatedAt  ClosedAt  ...  UpdatedAt  State  Additions  \
# RepoLanguage                                 ...
# C                    4          5         5  ...          5      5          5
# C#                   2          2         1  ...          2      2          2
# C++                  2          2         1  ...          2      2          2
# CSS                  1          1         1  ...          1      1          1
# Dart                 1          1         0  ...          1      1          1
# Dockerfile           2          2         2  ...          2      2          2
# Elixir               1          1         1  ...          1      1          1
# Go                   7          7         3  ...          7      7          7
# HTML                 4          4         4  ...          4      4          4
# Java                10         10        10  ...         10     10         10
# JavaScript          61         63        59  ...         63     63         63
# Jupyter Notebook     1          1         1  ...          1      1          1
# PHP                  2          2         2  ...          2      2          2
# Python              11         14        13  ...         14     14         14
# Ruby                 1          1         1  ...          1      1          1
# SCSS                 1          1         0  ...          1      1          1
# Shell                1          1         1  ...          1      1          1
# Solidity             1          1         1  ...          1      1          1
# TypeScript          19         21        19  ...         21     21         21
# Vue                  3          4         2  ...          4      4          4
#
#                   Deletions  ChangedFiles  CommitsTotalCount  CommitShas  \
# RepoLanguage
# C                         5             5                  5           5
# C#                        2             2                  2           2
# C++                       2             2                  2           2
# CSS                       1             1                  1           1
# Dart                      1             1                  1           1
# Dockerfile                2             2                  2           2
# Elixir                    1             1                  1           1
# Go                        7             7                  7           7
# HTML                      4             4                  4           4
# Java                     10            10                 10          10
# JavaScript               63            63                 63          12
# Jupyter Notebook          1             1                  1           1
# PHP                       2             2                  2           2
# Python                   14            14                 14          14
# Ruby                      1             1                  1           1
# SCSS                      1             1                  1           1
# Shell                     1             1                  1           1
# Solidity                  1             1                  1           1
# TypeScript               21            21                 21          21
# Vue                       4             4                  4           4
#
#                   ChatgptSharing  CommitSha  source_date
# RepoLanguage
# C                              5          0            5
# C#                             2          0            2
# C++                            2          0            2
# CSS                            1          0            1
# Dart                           1          0            1
# Dockerfile                     2          0            2
# Elixir                         1          0            1
# Go                             7          0            7
# HTML                           4          0            4
# Java                          10          0           10
# JavaScript                    63         51           63
# Jupyter Notebook               1          0            1
# PHP                            2          0            2
# Python                        14          0           14
# Ruby                           1          0            1
# SCSS                           1          0            1
# Shell                          1          0            1
# Solidity                       1          0            1
# TypeScript                    21          0           21
# Vue                            4          0            4
#
# [20 rows x 21 columns]

# %% [markdown]
# # Filter out Bash languages
