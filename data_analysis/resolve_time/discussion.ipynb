# %% [markdown]
# ### Importing Libraries and Data and Initialize Functions

# %%
import altair as alt
import pandas as pd
import numpy as np
from langdetect import detect
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

def is_english(row):
    try:
        return detect(row['Prompt']) == 'en' and detect(row['Answer']) == 'en'
    except:
        return False

def count_tokens(sentence):
    doc = nlp(sentence)
    return len([token for token in doc])

# %%
discussion = pd.read_csv('/Users/red/Desktop/CLONERepo/DevGPT/cleaned/discussion_total.csv')

# %% [markdown]
# ### Data Overview

# %%
discussion.head(1)
# Out:
#          Type                                     URL_discussion  \
# 0  discussion  https://github.com/orgs/deep-foundation/discus...
#
#            Author                     RepoName RepoLanguage  Number  \
# 0  FreePhoenix888  deep-foundation/Discussions          NaN      27
#
#                                              Title_x  \
# 0  Should we worry about imports perfomance in ha...
#
#                                                 Body             CreatedAt  \
# 0  My dialogue with chatgpt about it: https://cha...  2023-07-11T11:31:00Z
#
#   ClosedAt  ...                                       MentionedURL  \
# 0      NaN  ...  https://github.com/deep-foundation/Discussions...
#
#    MentionedProperty  MentionedAuthor  \
# 0      comments.body           Konard
#
#                                        MentionedText MentionedIsAnswer  \
# 0  https://chat.openai.com/share/1e0f86ff-2094-44...             False
#
#    MentionedUpvoteCount                                 URL_chatgptsharing  \
# 0                   1.0  https://chat.openai.com/share/1e0f86ff-2094-44...
#
#                                               Prompt  \
# 0  Can I always use await import instead of plain...
#
#                                               Answer  ListOfCode
# 0  The use of await import(...) and import ... in...          []
#
# [1 rows x 35 columns]

# %%
discussion.columns
# Out:
# Index(['Type', 'URL_discussion', 'Author', 'RepoName', 'RepoLanguage',
#        'Number', 'Title_x', 'Body', 'CreatedAt', 'ClosedAt', 'UpdatedAt',
#        'Closed', 'UpvoteCount', 'source_date', 'URL_chatgptsharing_x',
#        'Status', 'DateOfConversation', 'DateOfAccess', 'Title_y',
#        'NumberOfPrompts', 'TokensOfPrompts', 'TokensOfAnswers', 'Model',
#        'HTMLContent', 'URL_chatgptsharing_y', 'MentionedURL',
#        'MentionedProperty', 'MentionedAuthor', 'MentionedText',
#        'MentionedIsAnswer', 'MentionedUpvoteCount', 'URL_chatgptsharing',
#        'Prompt', 'Answer', 'ListOfCode'],
#       dtype='object')

# %% [markdown]
# ### Filtering and preprocessing the data

# %%
filtered_discussion = discussion.query("RepoLanguage == 'Python'")
filtered_discussion = filtered_discussion[filtered_discussion.apply(is_english, axis=1)]

# %%
filtered_discussion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 16 to 312
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Type                  60 non-null     object
#  1   URL_discussion        60 non-null     object
#  2   Author                60 non-null     object
#  3   RepoName              60 non-null     object
#  4   RepoLanguage          60 non-null     object
#  5   Number                60 non-null     int64
#  6   Title_x               60 non-null     object
#  7   Body                  60 non-null     object
#  8   CreatedAt             60 non-null     object
#  9   ClosedAt              0 non-null      object
#  10  UpdatedAt             60 non-null     object
#  11  Closed                60 non-null     bool
#  12  UpvoteCount           60 non-null     int64
#  13  source_date           60 non-null     int64
#  14  URL_chatgptsharing_x  60 non-null     object
#  15  Status                60 non-null     int64
#  16  DateOfConversation    60 non-null     object
#  17  DateOfAccess          60 non-null     object
#  18  Title_y               60 non-null     object
#  19  NumberOfPrompts       60 non-null     float64
#  20  TokensOfPrompts       60 non-null     float64
#  21  TokensOfAnswers       60 non-null     float64
#  22  Model                 60 non-null     object
#  23  HTMLContent           60 non-null     object
#  24  URL_chatgptsharing_y  60 non-null     object
#  25  MentionedURL          60 non-null     object
#  26  MentionedProperty     60 non-null     object
#  27  MentionedAuthor       60 non-null     object
#  28  MentionedText         60 non-null     object
#  29  MentionedIsAnswer     37 non-null     object
#  30  MentionedUpvoteCount  37 non-null     float64
#  31  URL_chatgptsharing    60 non-null     object
#  32  Prompt                60 non-null     object
#  33  Answer                60 non-null     object
#  34  ListOfCode            60 non-null     object
# dtypes: bool(1), float64(4), int64(4), object(26)
# memory usage: 16.5+ KB

# %%
filtered_discussion['Prompt_tokens'] = filtered_discussion['Prompt'].apply(count_tokens)
filtered_discussion['Answer_tokens'] = filtered_discussion['Answer'].apply(count_tokens)

# %%
filtered_discussion.head(1)
# Out:
#           Type                                     URL_discussion    Author  \
# 16  discussion  https://github.com/dtch1997/gpt-text-gym/discu...  dtch1997
#
#                  RepoName RepoLanguage  Number  \
# 16  dtch1997/gpt-text-gym       Python       7
#
#                                      Title_x  \
# 16  GPT decomposing missions using functions
#
#                                                  Body             CreatedAt  \
# 16  Message 1: Environment description\r\nMessage ...  2023-06-26T19:30:34Z
#
#    ClosedAt  ... MentionedAuthor  \
# 16      NaN  ...        dtch1997
#
#                                         MentionedText  MentionedIsAnswer  \
# 16  Message 1: Environment description\r\nMessage ...              False
#
#     MentionedUpvoteCount                                 URL_chatgptsharing  \
# 16                   1.0  https://chat.openai.com/share/1ee48447-8296-4a...
#
#                                                Prompt  \
# 16  You are an agent in a gridworld.\nThe environm...
#
#                                                Answer ListOfCode  \
# 16  Yes, I understand the rules and structure of t...         []
#
#    Prompt_tokens  Answer_tokens
# 16           601             13
#
# [1 rows x 37 columns]

# %%
print("filtered discussion data has")
print(str(len(filtered_discussion)) + " rows")
print(str(len(filtered_discussion['URL_discussion'].unique())) + " unique URLs")
# Out:
# filtered discussion data has
# 60 rows
# 8 unique URLs

# %%
filtered_discussion = filtered_discussion[['URL_discussion', 'RepoName', 'CreatedAt', 'ClosedAt', 'UpdatedAt', 'Closed']]
filtered_discussion.query('Closed == True')
# Out:
#                                         URL_discussion  \
# 16   https://github.com/dtch1997/gpt-text-gym/discu...
# 17   https://github.com/dtch1997/gpt-text-gym/discu...
# 18   https://github.com/dtch1997/gpt-text-gym/discu...
# 19   https://github.com/dtch1997/gpt-text-gym/discu...
# 20   https://github.com/dtch1997/gpt-text-gym/discu...
# 21   https://github.com/dtch1997/gpt-text-gym/discu...
# 22   https://github.com/dtch1997/gpt-text-gym/discu...
# 23   https://github.com/dtch1997/gpt-text-gym/discu...
# 24   https://github.com/dtch1997/gpt-text-gym/discu...
# 25   https://github.com/dtch1997/gpt-text-gym/discu...
# 26   https://github.com/dtch1997/gpt-text-gym/discu...
# 27   https://github.com/dtch1997/gpt-text-gym/discu...
# 28   https://github.com/dtch1997/gpt-text-gym/discu...
# 29   https://github.com/dtch1997/gpt-text-gym/discu...
# 30   https://github.com/dtch1997/gpt-text-gym/discu...
# 31   https://github.com/dtch1997/gpt-text-gym/discu...
# 32   https://github.com/dtch1997/gpt-text-gym/discu...
# 33   https://github.com/dtch1997/gpt-text-gym/discu...
# 34   https://github.com/dtch1997/gpt-text-gym/discu...
# 35   https://github.com/dtch1997/gpt-text-gym/discu...
# 36   https://github.com/dtch1997/gpt-text-gym/discu...
# 37   https://github.com/dtch1997/gpt-text-gym/discu...
# 38   https://github.com/dtch1997/gpt-text-gym/discu...
# 39   https://github.com/dtch1997/gpt-text-gym/discu...
# 105  https://github.com/dtch1997/gpt-text-gym/discu...
# 111     https://github.com/sugi-01096/72/discussions/3
# 131     https://github.com/sugi-01096/72/discussions/3
# 151     https://github.com/sugi-01096/72/discussions/3
# 171     https://github.com/sugi-01096/72/discussions/3
# 186  https://github.com/Significant-Gravitas/Auto-G...
# 227  https://github.com/HaroldMitts/VoAIce/discussi...
# 228  https://github.com/dtch1997/gpt-text-gym/discu...
# 229  https://github.com/dtch1997/gpt-text-gym/discu...
# 230  https://github.com/dtch1997/gpt-text-gym/discu...
# 231  https://github.com/dtch1997/gpt-text-gym/discu...
# 232  https://github.com/dtch1997/gpt-text-gym/discu...
# 234  https://github.com/dtch1997/gpt-text-gym/discu...
# 260  https://github.com/jasonacox/Powerwall-Dashboa...
# 261  https://github.com/jasonacox/Powerwall-Dashboa...
# 262  https://github.com/jasonacox/Powerwall-Dashboa...
# 263  https://github.com/jasonacox/Powerwall-Dashboa...
# 294  https://github.com/uuid6/prototypes/discussion...
# 295  https://github.com/uuid6/prototypes/discussion...
# 296  https://github.com/uuid6/prototypes/discussion...
# 297  https://github.com/uuid6/prototypes/discussion...
# 298  https://github.com/uuid6/prototypes/discussion...
# 299  https://github.com/uuid6/prototypes/discussion...
# 300  https://github.com/uuid6/prototypes/discussion...
# 301  https://github.com/uuid6/prototypes/discussion...
# 302  https://github.com/uuid6/prototypes/discussion...
# 303  https://github.com/uuid6/prototypes/discussion...
# 304  https://github.com/uuid6/prototypes/discussion...
# 305  https://github.com/uuid6/prototypes/discussion...
# 306  https://github.com/uuid6/prototypes/discussion...
# 307  https://github.com/uuid6/prototypes/discussion...
# 308  https://github.com/uuid6/prototypes/discussion...
# 309  https://github.com/uuid6/prototypes/discussion...
# 310  https://github.com/uuid6/prototypes/discussion...
# 311  https://github.com/uuid6/prototypes/discussion...
# 312  https://github.com/uuid6/prototypes/discussion...
#
#                           RepoName             CreatedAt ClosedAt  \
# 16           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 17           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 18           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 19           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 20           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 21           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 22           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 23           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 24           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 25           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 26           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 27           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 28           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 29           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 30           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 31           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 32           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 33           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 34           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 35           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 36           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 37           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 38           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 39           dtch1997/gpt-text-gym  2023-06-26T19:30:34Z      NaN
# 105          dtch1997/gpt-text-gym  2023-06-26T15:20:50Z      NaN
# 111                  sugi-01096/72  2023-06-14T02:10:49Z      NaN
# 131                  sugi-01096/72  2023-06-14T02:10:49Z      NaN
# 151                  sugi-01096/72  2023-06-14T02:10:49Z      NaN
# 171                  sugi-01096/72  2023-06-14T02:10:49Z      NaN
# 186  Significant-Gravitas/Auto-GPT  2023-06-18T21:51:35Z      NaN
# 227             HaroldMitts/VoAIce  2023-05-30T18:32:56Z      NaN
# 228          dtch1997/gpt-text-gym  2023-06-26T19:24:52Z      NaN
# 229          dtch1997/gpt-text-gym  2023-06-26T19:24:52Z      NaN
# 230          dtch1997/gpt-text-gym  2023-06-26T19:24:52Z      NaN
# 231          dtch1997/gpt-text-gym  2023-06-26T19:24:52Z      NaN
# 232          dtch1997/gpt-text-gym  2023-06-26T19:24:52Z      NaN
# 234          dtch1997/gpt-text-gym  2023-06-26T19:24:52Z      NaN
# 260  jasonacox/Powerwall-Dashboard  2023-07-17T05:20:17Z      NaN
# 261  jasonacox/Powerwall-Dashboard  2023-07-17T05:20:17Z      NaN
# 262  jasonacox/Powerwall-Dashboard  2023-07-17T05:20:17Z      NaN
# 263  jasonacox/Powerwall-Dashboard  2023-07-17T05:20:17Z      NaN
# 294               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 295               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 296               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 297               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 298               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 299               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 300               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 301               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 302               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 303               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 304               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 305               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 306               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 307               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 308               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 309               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 310               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 311               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
# 312               uuid6/prototypes  2023-06-07T15:06:44Z      NaN
#
#                 UpdatedAt  Closed
# 16   2023-06-26T19:36:50Z   False
# 17   2023-06-26T19:36:50Z   False
# 18   2023-06-26T19:36:50Z   False
# 19   2023-06-26T19:36:50Z   False
# 20   2023-06-26T19:36:50Z   False
# 21   2023-06-26T19:36:50Z   False
# 22   2023-06-26T19:36:50Z   False
# 23   2023-06-26T19:36:50Z   False
# 24   2023-06-26T19:36:50Z   False
# 25   2023-06-26T19:36:50Z   False
# 26   2023-06-26T19:36:50Z   False
# 27   2023-06-26T19:36:50Z   False
# 28   2023-06-26T19:36:50Z   False
# 29   2023-06-26T19:36:50Z   False
# 30   2023-06-26T19:36:50Z   False
# 31   2023-06-26T19:36:50Z   False
# 32   2023-06-26T19:36:50Z   False
# 33   2023-06-26T19:36:50Z   False
# 34   2023-06-26T19:36:50Z   False
# 35   2023-06-26T19:36:50Z   False
# 36   2023-06-26T19:36:50Z   False
# 37   2023-06-26T19:36:50Z   False
# 38   2023-06-26T19:36:50Z   False
# 39   2023-06-26T19:36:50Z   False
# 105  2023-06-26T17:21:42Z   False
# 111  2023-06-19T06:58:39Z   False
# 131  2023-06-19T06:58:39Z   False
# 151  2023-06-19T06:58:39Z   False
# 171  2023-06-19T06:58:39Z   False
# 186  2023-06-18T21:51:36Z   False
# 227  2023-05-30T19:01:27Z   False
# 228  2023-06-29T18:32:46Z   False
# 229  2023-06-29T18:32:46Z   False
# 230  2023-06-29T18:32:46Z   False
# 231  2023-06-29T18:32:46Z   False
# 232  2023-06-29T18:32:46Z   False
# 234  2023-06-29T18:32:46Z   False
# 260  2023-07-21T17:57:39Z   False
# 261  2023-07-21T17:57:39Z   False
# 262  2023-07-21T17:57:39Z   False
# 263  2023-07-21T17:57:39Z   False
# 294  2023-06-09T13:00:30Z   False
# 295  2023-06-09T13:00:30Z   False
# 296  2023-06-09T13:00:30Z   False
# 297  2023-06-09T13:00:30Z   False
# 298  2023-06-09T13:00:30Z   False
# 299  2023-06-09T13:00:30Z   False
# 300  2023-06-09T13:00:30Z   False
# 301  2023-06-09T13:00:30Z   False
# 302  2023-06-09T13:00:30Z   False
# 303  2023-06-09T13:00:30Z   False
# 304  2023-06-09T13:00:30Z   False
# 305  2023-06-09T13:00:30Z   False
# 306  2023-06-09T13:00:30Z   False
# 307  2023-06-09T13:00:30Z   False
# 308  2023-06-09T13:00:30Z   False
# 309  2023-06-09T13:00:30Z   False
# 310  2023-06-09T13:00:30Z   False
# 311  2023-06-09T13:00:30Z   False
# 312  2023-06-09T13:00:30Z   False

# %%
filtered_discussion.query('Closed == True')
# Out:
# Empty DataFrame
# Columns: [URL_discussion, RepoName, CreatedAt, ClosedAt, UpdatedAt, Closed]
# Index: []

# %%
filtered_discussion.dropna(subset=['ClosedAt'])
# Out:
# Empty DataFrame
# Columns: [URL_discussion, RepoName, CreatedAt, ClosedAt, UpdatedAt, Closed]
# Index: []

# %% [markdown]
# ### Data analysis and visualization

# %%
interactions_per_issue = filtered_discussion['URL_discussion'].value_counts()
avergae_interactions_per_issue = interactions_per_issue.mean()

print("average interactions per issue: " + str(avergae_interactions_per_issue))
# Out:
# average interactions per issue: 7.5
